# %%
import pandas as pd

df = pd.read_csv('traffic_cameras_metadata.csv')
df.head()
# Out:
#    Index                               description  milePost  \
# 0      1  I-270 & Old Hundred Rd (MD 109)(CAM 165)     22.27
# 1      2                        I-70 East of I-270     53.13
# 2      3                           US 50 AT MD 424     11.45
# 3      4                      I-97 AT NEW CUT ROAD     12.20
# 4      5             I-695 Median at MM32.3 (C027)     31.02
#
#                                       publicVideoURL        lat       lon  \
# 0  https://chart.maryland.gov/Video/GetVideo/7a00...  39.277300 -77.32360
# 1  https://chart.maryland.gov/Video/GetVideo/9201...  39.397610 -77.42188
# 2  https://chart.maryland.gov/Video/GetVideo/0001...  38.960420 -76.65623
# 3  https://chart.maryland.gov/Video/GetVideo/0001...  39.128563 -76.64165
# 4  https://chart.maryland.gov/Video/GetVideo/3801...  39.358448 -76.50345
#
#   routePrefix  routeSuffix  routeNumber cameraCategories  \
# 0          IS          NaN          270     ['Wash. DC']
# ...

# %%
df.columns
# Out:
# Index(['Index', 'description', 'milePost', 'publicVideoURL', 'lat', 'lon',
#        'routePrefix', 'routeSuffix', 'routeNumber', 'cameraCategories',
#        'cctvIp', 'commMode', 'opStatus', 'name', 'id',
#        'lastCachedDataUpdateTime'],
#       dtype='object')

# %%
for i in range(16):
    print(df[df['routeNumber'] == 270]['publicVideoURL'].iloc[i])
# Out:
# https://chart.maryland.gov/Video/GetVideo/7a00a1dc01250075004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/2100d19c00cc00180053fa36c4235c0a
# https://chart.maryland.gov/Video/GetVideo/a900598700f30074004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/9201113c036b0075004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/1501835800f700d700437a45351f0214
# https://chart.maryland.gov/Video/GetVideo/10027e5800f700d700437a45351f0214
# https://chart.maryland.gov/Video/GetVideo/8601655500f60074004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/2d00cd8100080075004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/df012178036c0075004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/f50009a903690075004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/520119f4036b0075004d823633235daa
# https://chart.maryland.gov/Video/GetVideo/bf014156024f0075004d823633235daa
# ...
